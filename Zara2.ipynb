# %% [markdown]
# <a href="https://colab.research.google.com/github/zaraavoyan/csphw2/blob/master/Zara2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/noisyneuron/training-dcgan
# Out:
# Cloning into 'training-dcgan'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 100 (delta 20), reused 35 (delta 13), pack-reused 55
# Receiving objects: 100% (100/100), 160.89 KiB | 1.07 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# !cd training-dcgan && pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 2.1MB 15.5MB/s
# ...
#      |████████████████████████████████| 880kB 51.5MB/s
# ...
#      |████████████████████████████████| 102kB 15.1MB/s
# ...
#      |████████████████████████████████| 354.4MB 48kB/s
# ...
#      |████████████████████████████████| 109.2MB 100kB/s
# ...
#      |████████████████████████████████| 17.3MB 202kB/s
# ...
#      |████████████████████████████████| 317kB 66.9MB/s
# ...
#      |████████████████████████████████| 81kB 12.8MB/s
# ...
#      |████████████████████████████████| 1.2MB 47.4MB/s
# ...
#      |████████████████████████████████| 491kB 48.9MB/s
# ...
#      |████████████████████████████████| 3.2MB 48.8MB/s
# ...
#   Created wheel for chainer: filename=chainer-6.2.0-cp36-none-any.whl size=880596 sha256=168b13b12f892b4e632fa7ac8119834cebf6cd89e46c8d7b6f5878f6cb346376
#   Stored in directory: /root/.cache/pip/wheels/2e/be/c5/6ee506abcaa4a53106f7d7671bbee8b4e5243bc562a9d32ad1
# ...

# %%
# !cd training-dcgan && ./datatool.py --size 64
# Out:
# I0225 06:02:30.070350 140321506727808 datatool.py:125] Creating custom dataset ./dataset from ./images
#
# ./images/IMG_0701.JPG
# ./images/IMG_0702.JPG
# ./images/IMG_0704.JPG
# ./images/IMG_0706.JPG
# ./images/IMG_0711.JPG
# ./images/Murtić_G05_-_58x88_cm_G_180125.jpg
# ./images/tumblr_ommjm6XHQ71u6x3h6o2_r1_1280.jpg
# ./images/tumblr_owtimyz6Ek1vc1b98o1_1280.jpg
# ./images/IMG_0705.JPG
# ./images/tumblr_mrr4m7gllP1srbfazo1_1280.jpg
# ./images/IMG_0703.JPG
# ./images/tumblr_oir3a5lHeY1vc1b98o1_1280.jpg
# ./images/IMG_0712.JPG
#
# I0225 06:02:30.344537 140321506727808 datatool.py:174] Added 13 images.
# I0225 06:02:30.345036 140321506727808 datatool.py:176] Converting to numpy array
# I0225 06:02:30.347076 140321506727808 datatool.py:179] Saving numpy array to ./dataset.

# %%
# !cd training-dcgan && ./chainer_dcgan.py --arch dcgan64 --image_size 64
# Out:
# Streaming output truncated to the last 5000 lines.
# 433723      88100       19016.9       13.3729       0.000473249   0.000603476
#      total [############################################......] 88.11%
# this epoch [###############...................................] 30.77%
#      88110 iter, 433772 epoch / 100000 iterations
#     4.6369 iters/sec. Estimated time to finish: 0:42:44.187547.
#      total [############################################......] 88.12%
# this epoch [##########################........................] 53.85%
#      88120 iter, 433821 epoch / 100000 iterations
#      4.637 iters/sec. Estimated time to finish: 0:42:42.003342.
#      total [############################################......] 88.13%
# this epoch [######################################............] 76.92%
#      88130 iter, 433870 epoch / 100000 iterations
#     4.6373 iters/sec. Estimated time to finish: 0:42:39.686269.
#      total [############################################......] 88.14%
# ...

# %%
# !cd training-dcgan && ./dcgan_chainer_to_keras.py --arch dcgan64 --chainer_model_path result/SmoothedGenerator_50000.npz
# Out:
# Using TensorFlow backend.
# W0225 15:04:16.742613 139735605647232 deprecation_wrapper.py:119] From ./dcgan_chainer_to_keras.py:260: The name tf.disable_eager_execution is deprecated. Please use tf.compat.v1.disable_eager_execution instead.
#
# Tensorflow.js model path:  result/SmoothedGenerator_50000_tfjs
# ...
# weight
# --------------------------------------------------------------------------------
# bn0/N ()
# bn0/avg_mean (8192,)
# bn0/avg_var (8192,)
# bn0/beta (8192,)
# bn0/gamma (8192,)
# bn1/N ()
# bn1/avg_mean (256,)
# bn1/avg_var (256,)
# bn1/beta (256,)
# bn1/gamma (256,)
# bn2/N ()
# bn2/avg_mean (128,)
# bn2/avg_var (128,)
# bn2/beta (128,)
# bn2/gamma (128,)
# bn3/N ()
# bn3/avg_mean (64,)
# bn3/avg_var (64,)
# bn3/beta (64,)
# bn3/gamma (64,)
# dc1/W (512, 256, 4, 4)
# dc1/b (256,)
# dc2/W (256, 128, 4, 4)
# dc2/b (128,)
# dc3/W (128, 64, 4, 4)
# dc3/b (64,)
# dc4/W (64, 3, 4, 4)
# dc4/b (3,)
# l0/W (8192, 128)
# l0/b (8192,)
# ...
